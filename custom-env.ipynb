# %%
import gymnasium as gym
from matplotlib import pyplot as plt

env = gym.make('custom-intersection-v0', render_mode="rgb_array")

env.unwrapped.configure({
    "collision_reward": -50,
})
env.reset()
done = False
while not done:
    action = env.action_space.sample()
    obs, reward, done, truncated, info = env.step(action)
    # print("Shape:", obs.shape)
    print("Reward:", reward)
    # print("Done:", done)
    # print("Truncated:", truncated)
    print("Info:", info)
    print("Action:", action)
    # print("Actions Array:", env.unwrapped.get_available_actions())
    env.render()
env.reset()
# for _ in range(3):
#     action = env.action_type.actions_indexes["IDLE"]
#     obs, reward, done, truncated, info = env.step(action)
    # env.render()

plt.imshow(env.render())
plt.show()

# import gymnasium as gym

# env = gym.make("Humanoid-v4", render_mode="human")
# observation, info = env.reset()

# for _ in range(1000):
#     action = env.action_space.sample()  # agent policy that uses the observation and info
#     observation, reward, terminated, truncated, info = env.step(action)

#     if terminated or truncated:
#         observation, info = env.reset()

# env.close()
# Out:
# Reward: 0.0
# Info: {'speed': 5.439885290443771, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.6958091411086906
# Info: {'speed': 8.391618282217381, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.6958091411086906, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.6958091411086906,), 'agents_dones': (False,)}
# Action: 2
# Reward: 0.0
# Info: {'speed': 5.16503177808694, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.8826431623451909, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.15083333181800335, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 1
# Reward: 0.0
# Info: {'speed': 0.025775641797157408, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.004404753923071981, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 3.731755664804245, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 2
# Reward: 0.0
# Info: {'speed': 0.6377131376144953, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.10897767228483789, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.018623002030421984, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 3.734185396122787, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 2
# Reward: 0.0
# Info: {'speed': 0.638128350110137, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 3.840051571397582, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 2
# Reward: 0.0
# Info: {'speed': 0.6562196339094684, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 0.11214021476580105, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 1
# Reward: 0.0
# Info: {'speed': 0.01916344333192396, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 1
# Reward: 0.0
# Info: {'speed': 0.0032748070003505636, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 1
# Reward: 0.0
# Info: {'speed': 0.0005596259870312334, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 1
# Reward: 0.0
# Info: {'speed': 9.563349697467869e-05, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 1.634263946912716e-05, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 2.792764808010622e-06, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 4.772506477669465e-07, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 8.155652067107533e-08, 'crashed': False, 'action': 0, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 0
# Reward: 0.0
# Info: {'speed': 3.7310029581194186, 'crashed': False, 'action': 2, 'rewards': {'collision_reward': 0.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (0.0,), 'agents_dones': (False,)}
# Action: 2
# Reward: -50.0
# Info: {'speed': 1.9726043341987636, 'crashed': True, 'action': 2, 'rewards': {'collision_reward': 1.0, 'high_speed_reward': 0.0, 'arrived_reward': 0.0, 'on_road_reward': 1.0}, 'agents_rewards': (-50.0,), 'agents_dones': (True,)}
# Action: 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
